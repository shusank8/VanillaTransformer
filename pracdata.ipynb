# %%
print("loading dataset")
import kagglehub
# Out:
# loading dataset

# %%
# # Download latest version
# path = kagglehub.dataset_download("jigarpanjiyar/english-to-manipuri-dataset")

# print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.12).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/jigarpanjiyar/english-to-manipuri-dataset?dataset_version_number=1...
# 100%|██████████| 3.04G/3.04G [05:20<00:00, 10.2MB/s]
# Extracting files...
# Path to dataset files: /Users/shusanketbasyal/.cache/kagglehub/datasets/jigarpanjiyar/english-to-manipuri-dataset/versions/1

# %%
import pandas as pd
import os

# %%
path = "/Users/shusanketbasyal/.cache/kagglehub/datasets/jigarpanjiyar/english-to-manipuri-dataset/versions/1"
os.listdir(path)
# Out:
# ['1_Eng.txt', 'english-nepali.xlsx', '1_Nepali.txt']

# %%
df = pd.read_excel(path + "/english-nepali.xlsx")

# %%
df["english_sent"] = df["english_sent"].apply(lambda x: str(x))
df["nepali_sent"] = df["nepali_sent"].apply(lambda x: str(x))

# %%
eng = df["english_sent"].tolist()
nep = df["nepali_sent"].tolist()

# %%
df.head()
# Out:
#                                         english_sent  \
# 0  It happened after the death of Saul, when Davi...
# 1  it happened on the third day, that behold, a m...
# 2  David said to him, "Where do you come from?" H...
# 3  David said to him, "How did it go? Please tell...
# 4  David said to the young man who told him, "How...
#
#                                          nepali_sent
# 0  दाऊदले अमालेकीहरूलाई हराएर पछि सिकलग गए। यो शा...
# 1  तब तेस्रो दिनमा एउटा जवान सैनिक सिकलगमा आयो। त...
# 2  दाऊदले त्यसलाई सोधे, “तिमी कहाँबाट आयौ?” त्यस ...
# 3  दाऊदले भने, “मलाई भन, के भयो?” त्यसले भन्यो, “...
# 4  दाऊदले त्यस सैनिकलाई भने, “तिमीले कसरी जान्यौ ...

# %%
len(eng), len(nep)
# Out:
# (151937, 151937)

# %%
eng_com = []
nep_com = []
eng_lens = []
step = 15
for x in range(0, len(eng), step):
    engobj = " ".join(eng[x : x + step])
    eng_com.append(engobj)
    eng_lens.append(len(engobj.split(" ")))

# %%
import matplotlib.pyplot as plt
from collections import Counter


# Count occurrences
counts = Counter(eng_lens)

# Extract unique numbers and their counts
x = list(counts.keys())
y = list(counts.values())

# Create the bar graph
plt.bar(x, y)
plt.xlabel("Number")
plt.ylabel("Occurrences")
plt.title("Occurrences of Each Number")
plt.show()

# %%
eng_lens[0]
# Out:
# 396

# %%
for i, x in enumerate(eng_com[0].split(" ")):
    print(x, i)
# Out:
# It 0
# happened 1
# after 2
# the 3
# death 4
# of 5
# Saul, 6
# when 7
# David 8
# was 9
# returned 10
# from 11
# the 12
# slaughter 13
# of 14
# the 15
# Amalekites, 16
# and 17
# David 18
# had 19
# stayed 20
# two 21
# days 22
# in 23
# Ziklag; 24
# it 25
# happened 26
# on 27
# the 28
# third 29
# day, 30
# that 31
# behold, 32
# a 33
# man 34
# came 35
# out 36
# of 37
# the 38
# camp 39
# from 40
# Saul, 41
# with 42
# his 43
# clothes 44
# torn, 45
# and 46
# earth 47
# on 48
# his 49
# head: 50
# and 51
# so 52
# it 53
# was, 54
# when 55
# he 56
# came 57
# to 58
# David, 59
# that 60
# he 61
# fell 62
# to 63
# the 64
# earth, 65
# and 66
# showed 67
# respect. 68
# David 69
# said 70
# to 71
# him, 72
# "Where 73
# do 74
# you 75
# come 76
# from?" 77
# He 78
# said 79
# to 80
# him, 81
# "I 82
# have 83
# escaped 84
# out 85
# of 86
# the 87
# camp 88
# of 89
# Israel." 90
# David 91
# said 92
